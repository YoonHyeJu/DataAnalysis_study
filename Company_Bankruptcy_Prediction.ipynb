# %% [markdown]
# # 회사 파산 예측 데이터

# %% [markdown]
# 이 데이터는 1999년부터 2009년까지 대만 경제 저널에서 수집된 정보입니다. 회사 파산은 대만 증권 거래소의 비즈니스 규정에 따라 정의되었습니다.
# 위 데이터를 가지고 회사의 파산을 예측해볼 수 있습니다.
#
# 데이터 출처: https://www.kaggle.com/fedesoriano/company-bankruptcy-prediction

# %% [markdown]
# ## 데이터 설명

# %% [markdown]
# |열 이름|설명|
# |-------|----|
# |파산?|클래스 레이블|
# |이자 전 ROA (C) 및이자 전 감가 상각|총 자산 수익률 (C)|
# |ROA (A)이자 전 및 %|총 자산 수익률 (A)|
# |ROA (B) 세후이자 및 감가 상각 전|총 자산 수익률 (B)|
# |영업 총 이익|총 이익 / 순 매출|
# |실현 판매 총 이익|실현 총 이익 / 순 매출|
# |영업 이익률|영업 이익 / 순매출|
# |세전 순 이자율|세전 소득 / 순매출|
# |세후 순 이자율|순이익 / 순매출|
# |비 산업 소득 및 지출 / 수익|영업 외 순이익 비율|
# |연속 이자율 (세후)|순이익-처분 손익 제외 / 순매출|
# |운영 비율|운영비 / 순매출|
# |연구 개발 비율|(연구 개발비) / 순매출|
# |현금 흐름 율|영업 / 유동 부채로 인한 현금 흐름|
# |이자 부채 이자율|이자부 부채 / 자본|
# |세율 (A)|유효 세율|
# |주당 순 가치 (B)|장부가 주당 (B)|
# |주당 순 가치 (A)|주당 장부가 (A)|
# |주당 순 가치 (C)|주당 장부가 (C)|
# |지난 사계절의 영구 EPS|EPS -순이익|
# |주당 현금 흐름||
# |주당 수익 (Yuan ¥)|주당 판매|
# |주당 영업 이익 (Yuan ¥)|주당 영업 이익|
# |주당 세전 순이익 (Yuan ¥)|주당 세전 소득|
# |총 실현 판매 이익 증가율||
# |영업 이익 증가율|영업 이익 증가율|
# |세후 순이익 증가율|당기 순이익 증가율 : 순이익 증가율|
# |정기 순이익 증가율|세후 연속 영업 이익|
# |지속적인 순이익 증가율|순이익 -처분 증가율 제외|
# |총자산 증가율|총자산 증가율|
# |순 가치 증가율|총 자본 증가율|
# |총자산 수익 증가율 비율|총자산 증가율|
# |현금 재투자 %|현금 재투자 비율|
# |유동 비율||
# |당좌 비율|산성 테스트|
# |이자 비용 비율|이자 비용 / 총 수익|
# |총 부채 / 총 순자산|총 부채 / 자본 비율|
# |부채 비율 %|부채 / 총자산|
# |순자산 / 자산|자기 자본 / 총자산|
# |장기 자금 적합성 비율 (A)|(장기 부채 + 자본) / 고정 자산|
# |차입 의존성|이자 부채 비용|
# |우발 부채 / 순자산|우발 부채 / 자본|
# |영업 이익 / 납부 자본|영업 이익 / 자본|
# |세전 순이익 / 납부 자본|세전 이익 / 자본|
#
# X44-재고 및 미수금 / 순 가치 : (재고 + 미수금) / 자본
#
# X45-총 자산 회전율
#
# X46-미수금 회전율
#
# X47-평균 수 금일 : 미수금 미결 일수
#
# X48-재고 회전율 (회)
#
# X49-고정 자산 회전율 빈도
#
# X50-순자산 회전율 (회) : 자기 자본 회전율
#
# X51-1 인당 수익 : 직원당 판매
#
# X52-1 인당 영업 이익 : 직원당 영업 소득
#
# X53-1 인당 할당 비율 : 직원당 고정 자산
#
# X54-총액에 대한 운전 자본 자산
#
# X55- 당좌 자산 / 총 자산
#
# X56- 유동 자산 / 총 자산
#
# X57-현금 / 총 자산
#
# X58-당좌 자산 / 유동 부채
#
# X59-현금 / 유동 부채
#
# X60- 자산 유동 부채
#
# X61-부채에 대한 운영 자금
#
# X62-재고 / 유동 자본
#
# X63-재고 / 유동 부채
#
# X64-유동 부채 / 부채
#
# X65-운전 자본 / 자본
#
# X66 -유동 부채 / 자본
#
# X67-유동 자산에 대한 장기 부채
#
# X68-이익 잉여금
#
# X69-총 수익 / 총비용
#
# X70-총비용/ 자산
#
# X71-유동 자산 회전율 : 유동 자산 대 매출
#
# X72-빠른 자산 회전율 비율 : Quick Assets to Sales
#
# X73-Working Capitcal Turnover Rate : Working Capital to Sales
#
# X74 - 현금 회전율 속도 : 판매에 현금
#
# X75 - 판매에 대한 현금 흐름
#
# X76 - 자산에 대한 고정 자산
#
# X77 - 책임에 현재 책임
#
# X78 - 주식에 현재 책임
#
# X79 - 장기 책임에 자본
#
# X80 - 현금 흐름 총자산
#
# X81 - 부채
#
# X82에 대한 현금 흐름- 자산
#
# X83에 대한 CFO-자본에 대한 현금 흐름
#
# X84-유동 자산에 대한 유동 부채
#
# X85-부채-자산 플래그 : 총 부채가 총 자산을 초과하면 1, 그렇지 않으면 0
#
# X86-총 자산에 대한 순이익
#
# X87-총 자산 GNP 가격으로
#
# X88-신용 없음 간격
#
# X89-매출 총 이익
#
# X90-주주 자본 순이익
#
# X91- 자본 부채
#
# X92-재무 레버리지 (DFL)
#
# X93-이자 보상 비율 (EBIT에 대한이자 비용)
#
# X94-순이익 플래그 : 지난 2 년 동안 순이익이 음수이면 1, 그렇지 않으면 0
#
# X95-부채에 대한 자본

# %%
import numpy as np
import pandas as pd
import matplotlib as mlp
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = 'Company_Bankruptcy_data.csv'
data = pd.read_csv(file_path)

data
# Out:
#       Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0             1                                           0.370594
# 1             1                                           0.464291
# 2             1                                           0.426071
# 3             1                                           0.399844
# 4             1                                           0.465022
# ...         ...                                                ...
# 6814          0                                           0.493687
# 6815          0                                           0.475162
# 6816          0                                           0.472725
# 6817          0                                           0.506264
# 6818          0                                           0.493053
#
#        ROA(A) before interest and % after tax  \
# 0                                    0.424389
# 1                                    0.538214
# ...

# %% [markdown]
# ## 데이터 백업

# %%
data_copy = data.copy()
data_copy.to_csv('bankruptcy_copy.csv')

copy_file_path = 'bankruptcy_copy.csv'
data_copy = pd.read_csv(copy_file_path)
data_copy
# Out:
#       Unnamed: 0  Bankrupt?  \
# 0              0          1
# 1              1          1
# 2              2          1
# 3              3          1
# 4              4          1
# ...          ...        ...
# 6814        6814          0
# 6815        6815          0
# 6816        6816          0
# 6817        6817          0
# 6818        6818          0
#
#        ROA(C) before interest and depreciation before interest  \
# 0                                              0.370594
# 1                                              0.464291
# 2                                              0.426071
# 3                                              0.399844
# 4                                              0.465022
# ...                                                 ...
# 6814                                           0.493687
# 6815                                           0.475162
# 6816                                           0.472725
# ...

# %% [markdown]
# ## 데이터 정보보기

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6819 entries, 0 to 6818
# Data columns (total 96 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Bankrupt?                                                 6819 non-null   int64
#  1    ROA(C) before interest and depreciation before interest  6819 non-null   float64
#  2    ROA(A) before interest and % after tax                   6819 non-null   float64
#  3    ROA(B) before interest and depreciation after tax        6819 non-null   float64
#  4    Operating Gross Margin                                   6819 non-null   float64
#  5    Realized Sales Gross Margin                              6819 non-null   float64
#  6    Operating Profit Rate                                    6819 non-null   float64
#  7    Pre-tax net Interest Rate                                6819 non-null   float64
# ...

# %% [markdown]
# data는 96개의 컬럼으로 이루어져 있으며 그중 Bankrupt?는 예측 라벨을 의미한다.
#
# 총 6819개의 row가 존재하며 각 값은 연속형 데이터로 이루어져 있다.
#
# null값은 존재하지 않는다.

# %%
data.describe()
# Out:
#          Bankrupt?   ROA(C) before interest and depreciation before interest  \
# count  6819.000000                                        6819.000000
# mean      0.032263                                           0.505180
# std       0.176710                                           0.060686
# min       0.000000                                           0.000000
# 25%       0.000000                                           0.476527
# 50%       0.000000                                           0.502706
# 75%       0.000000                                           0.535563
# max       1.000000                                           1.000000
#
#         ROA(A) before interest and % after tax  \
# count                              6819.000000
# mean                                  0.558625
# std                                   0.065620
# min                                   0.000000
# 25%                                   0.535543
# ...

# %% [markdown]
# ## 컬럼명 변경

# %%
data = data.rename({'Bankrupt?':'Bankrupt'}, axis='columns')

data
# Out:
#       Bankrupt   ROA(C) before interest and depreciation before interest  \
# 0            1                                           0.370594
# 1            1                                           0.464291
# 2            1                                           0.426071
# 3            1                                           0.399844
# 4            1                                           0.465022
# ...        ...                                                ...
# 6814         0                                           0.493687
# 6815         0                                           0.475162
# 6816         0                                           0.472725
# 6817         0                                           0.506264
# 6818         0                                           0.493053
#
#        ROA(A) before interest and % after tax  \
# 0                                    0.424389
# 1                                    0.538214
# ...

# %%
# outcome 분포 확인
data['Bankrupt'].value_counts()
# Out:
# 0    6599
# 1     220
# Name: Bankrupt, dtype: int64

# %% [markdown]
# ## 데이터 시각화

# %%
plt.figure(figsize=(20,20))
sns.set_style('whitegrid')
sns.set_palette('bwr')
sns.boxplot(data = data.drop(['Bankrupt'], axis=1), orient = 'h', color = 'blue')
plt.title('Data range')
plt.show()

# %%
data.hist(figsize = (50,50), bins = 50)
plt.show()

# %%
corrMatt = data.corr()
top_corr_feature = corrMatt.index[abs(corrMatt["Bankrupt"])>=0.2]

plt.figure(figsize=(10,10))
g = sns.heatmap(data[top_corr_feature].corr(), annot = True)
plt.show()
# Out:
# Index(['Bankrupt', ' ROA(C) before interest and depreciation before interest',
#        ' ROA(A) before interest and % after tax',
#        ' ROA(B) before interest and depreciation after tax',
#        ' Persistent EPS in the Last Four Seasons',
#        ' Per Share Net profit before tax (Yuan ¥)', ' Debt ratio %',
#        ' Net worth/Assets', ' Net profit before tax/Paid-in capital',
#        ' Retained Earnings to Total Assets', ' Net Income to Total Assets'],
#       dtype='object')

# %% [markdown]
# - 'Bankrupt'는 'Net Income to Total Assets(총자산순이익)'과 음의 상관관계가 있다.
# - 'Bankrupt'는 'ROA(C) before interest and depreciation before interest'과 음의 상관관계가 있다.
# - 'Bankrupt'는 'ROA(A) before interest and % after tax'과 음의 상관관계가 있다.
# - 'Bankrupt'는 'ROA(B) before interest and depreciation after tax'과 음의 상관관계가 있다.
# - 'Bankrupt'는 'Persistent EPS in the Last Four Seasons'과 음의 상관관계가 있다.
# - 'Bankrupt'는 ' Per Share Net profit before tax (Yuan ¥)'과 음의 상관관계가 있다.
# - 'Bankrupt'는 'Debt ratio %'과 양의 상관관계가 있다.
# - 'Bankrupt'는 'Net worth/Assets'과 음의 상관관계가 있다.
# - 'Bankrupt'는 'Net profit before tax/Paid-in capital'과 음의 상관관계가 있다.
# - 'Bankrupt'는 'Retained Earnings to Total Assets'과 음의 상관관계가 있다.
# - 'Bankrupt'는 'Net Income to Total Assets'과 음의 상관관계가 있다.
#
# => 총수익이 적을수록 파산율이 증가하는 것으로 보인다.

# %% [markdown]
# ## 머신러닝

# %% [markdown]
# * 머신러닝 알고리즘 선택표
# 출처: https://gem1n1.tistory.com/13
#
# |1차 분류|2차 분류|알고리즘|설명|
# |--------|--------|--------|----|
# |지도학습|회귀형|LinearRegression|구현이 간단하고 트레이닝이 빠르다|
# |지도학습|회귀형|LassoRegression|데이터에 대한 어떤 분포 가정도 하지 않기 때문에 Linear Regression과 비교해 예측력이 더 높다. Lasso는 유의한 변수들만 사용한다|
# |지도학습|회귀형|RidgeRegression|데이터에 대한 어떤 분포 가정도 하지 않기 때문에 Linear Regression과 비교해 예측력이 더 높다. Ridge는 유의하지 않아 보이는 변수들의 계수를 감소시킨다|
# |지도학습|회귀형/분류형|Decision Tree|결과를 이해, 설명하기 쉬움(높은 해석력). 사용하는 나무의 개수를 늘릴수록 보편적인 예측결과를 얻을 수 있다.(n_estimator 옵션|
# |지도학습|분류형|LogisticRegression|레이블이 0,1의 바이너리 분류형 값을 가지는 경우 사용할 수 있다. (이항분포 사정). 선형 표현식을 가지므로 높은 해석렬을 가진다|
# |지도학습|분류형|Naive Bayes, 서포트 벡터 머신(SVM)|고차원의 데이터에 주로 사용|
# |지도학습|분류형|KNeighborsClassifier|저차원의 데이터에 주로 사용.(차원이 높아지면 모델의 성능이 낮아지는 경향을 보이므로, 많은 데이터를 확보해야 한다. 차원축소 기법을 함께 사용하는 것도 좋은 방법이다.|
# |지도학습|분류형|신경망|높은 예측력이 요구될 때에 주로 사용되는 알고리즘. 고차원, 다량의 데이터에서 최고의 예측력을 보인다.|
# |비지도학습|클러스터링|K 평균 군집화|클러스터링 그룹 개수가 정해져 있을 때|
# |비지도학습|클러스터링|Mini Batch K 평균 군집화|클러스터링 그룹 개수가 정해져 있고, 대량 데이터를 처리 할 때 (10000건 이상)|
# |비지도학습|클러스터링|MeanShift|클러스터링 그룹 개수가 정해져 있지 않을 때|
# |비지도학습|차원 축소|주성분분석 (PCA)|차원 축소 가능, 해석력 저하|

# %%
from sklearn import model_selection
from sklearn import metrics

# 전처리
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# 모델
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

# %%
# 데이터 세트 분류
x_data=data[top_corr_feature]
x_data = x_data.drop(['Bankrupt'], axis = 1)

y_data=data['Bankrupt']

# %%
# 데이터 전처리
standard = MinMaxScaler()
x_scaled = standard.fit_transform(x_data)

print(x_scaled[:5])
# Out:
# [[0.37059426 0.42438945 0.40574977 0.16914059 0.13873616 0.20757626
#   0.79242374 0.13775733 0.90322477 0.71684534]
#  [0.46429094 0.53821413 0.51673002 0.20894393 0.1699179  0.17117635
#   0.82882365 0.16896162 0.93106522 0.79529714]
#  [0.42607127 0.49901875 0.47229509 0.1805805  0.14280334 0.2075158
#   0.7924842  0.14803559 0.90990336 0.7746697 ]
#  [0.399844   0.45126472 0.45773328 0.19372223 0.14860285 0.15146476
#   0.84853524 0.14756052 0.90690216 0.73955453]
#  [0.46502218 0.53843218 0.52229777 0.21253664 0.16841154 0.10650905
#   0.89349095 0.16746098 0.9138502  0.79501587]]

# %%
# 학습 데이터와 테스트 데이터로 분류
y_data=y_data.values

x_train, x_test, y_train, y_test = model_selection.train_test_split(x_scaled, y_data, test_size=0.3, random_state=42)

# %% [markdown]
# ### Logistic Regression

# %%
lr_model = LogisticRegression()
lr_model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
# 학습 정확도
print(lr_model.score(x_train, y_train))
# Out:
# 0.9712968782736224

# %%
# 테스트 정확도
print(lr_model.score(x_test, y_test))
# Out:
# 0.9633431085043989

# %% [markdown]
# ### Decision Tree

# %%
dt_model = DecisionTreeClassifier()
dt_model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# 학습 정확도
print(dt_model.score(x_train, y_train))
# Out:
# 1.0

# %%
# 테스트 정확도
print(dt_model.score(x_test, y_test))
# Out:
# 0.9550342130987293

# %% [markdown]
# ### SVM

# %%
svc_model = SVC()
svc_model.fit(x_train, y_train)
# Out:
# SVC()

# %%
# 학습 정확도
print(svc_model.score(x_train, y_train))
# Out:
# 0.9702493190865283

# %%
# 테스트 정확도
print(svc_model.score(x_test, y_test))
# Out:
# 0.9618768328445748
